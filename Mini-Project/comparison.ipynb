# %% [markdown]
# # 1st Mini-Project Hand-in for Numerical Scientific Computing
#
# First, import the different versions:

# %%
from looped import plot_naive
from vectorized import plot_vectorized
from numb_opti import plot_looped_optimized, plot_vectorized_optimized

# %% [markdown]
# ## Naive (loops) Version

# %%
plot_naive()

# %% [markdown]
# As we can see, the naive version takes 47.15 seconds to run
#
# ## Numpy (vectorized) Version

# %%
plot_vectorized()

# %% [markdown]
# In this numpy vectorized version, the algorithm runs in 33.19 seconds
#
# ## Numba-Optimized Versions
# There are two numba-optimized versions of this algorithm; a loop version, and a vectorized version
#
# ### Loop Version

# %%
plot_looped_optimized()

# %% [markdown]
# We see that the numba-optimized version of the loop algorithm takes 0.53 seconds to run
#
# ### Vectorized Version

# %%
plot_vectorized_optimized()

# %% [markdown]
# The numba-optimized version of the vectorized algorithm runs in 4.47 seconds - this seems to be because numba lacks support of fancy indexing with 2D arrays, and therefore has to fall back to object mode, and that part of the code then runs in the interpreter.
#
# To solve this, one could rewrite the vectorized algorithm to avoid the use of fancy indexing with 2D arrays.

# %% [markdown]
# ## Parallel Version Using Multiprocessing
