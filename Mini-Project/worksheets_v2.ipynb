# %%
import numpy as np
from looped_updated import plot_naive

plot_naive(np.float16)

# %%
plot_naive(np.float32)

# %%
plot_naive(np.float64)

# %%
plot_naive(np.longdouble)

# %% [markdown]
# As we can see from the above examples, there are improvements for increased precision up until float128, where there is a drop in performance.
